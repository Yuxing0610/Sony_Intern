# %%
import numpy as np
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import CIFAR10, MNIST
from torch.utils.data import DataLoader, TensorDataset

import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
import os

DEVICE = torch.device('cuda')
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
def switch_to_device(dataset,device=None):
    final_X, final_Y = [], []
    for x, y in dataset:
        final_X.append(x)
        final_Y.append(y)
    X = torch.stack(final_X)
    Y = torch.tensor(final_Y)
    if device is not None:
        X = X.to(device)
        Y = Y.to(device)
    return TensorDataset(X, Y)

# %%
def get_Cifar10_dl(batch_size_train=256, batch_size_eval=1024, device=DEVICE):
    transform = transforms.Compose([transforms.ToTensor()])
    
    data_train = CIFAR10('./datasets', train=True, download=True, transform=transform)
    data_train = switch_to_device(data_train, device=device)
    data_train, data_valid = torch.utils.data.random_split(data_train, [45000,5000])
    
    data_test = CIFAR10('./datasets', train=False, download=True, transform=transform)
    data_test = switch_to_device(data_test, device=device)
    
    train_dl = DataLoader(data_train, batch_size=batch_size_train, shuffle=True)
    valid_dl = DataLoader(data_valid, batch_size=batch_size_eval, shuffle=False)
    test_dl = DataLoader(data_test, batch_size=batch_size_eval, shuffle=False)
    
    return train_dl, valid_dl, test_dl

# %%
def get_mnist_dl(batch_size_train=1024, batch_size_eval=1024, device=torch.device('cuda')):
    transform = transforms.Compose([transforms.ToTensor(), transforms.Lambda(lambda x: torch.flatten(x))])
    
    data_train = MNIST('./datasets', train=True, download=True, transform=transform)
    data_train = switch_to_device(data_train, device=device)
    data_train, data_valid = torch.utils.data.random_split(data_train, [55000,5000])
    
    data_test = MNIST('./datasets', train=False, download=True, transform=transform)
    data_test = switch_to_device(data_test, device=device)
    
    train_dl = DataLoader(data_train, batch_size=batch_size_train, shuffle=True)
    valid_dl = DataLoader(data_valid, batch_size=batch_size_eval, shuffle=False)
    test_dl = DataLoader(data_test, batch_size=batch_size_eval, shuffle=False)
    
    return train_dl, valid_dl, test_dl

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def print_stats(stats):

  fig, (ax1, ax2) = plt.subplots(1,2,figsize=(7,3), dpi=110)
  ax1.grid()
  ax2.grid()

  ax1.set_title("ERM loss")
  ax2.set_title("Valid Acc")
  
  ax1.set_xlabel("iterations")
  ax2.set_xlabel("iterations")

  itrs = [x[0] for x in stats['train-loss']]
  loss = [x[1].cpu().detach().numpy() for x in stats['train-loss']]
  ax1.plot(itrs, loss)

  itrs = [x[0] for x in stats['valid-acc']]
  acc = [x[1] for x in stats['valid-acc']]
  ax2.plot(itrs, acc)

  ax1.set_ylim(0.0, max(loss))
  ax2.set_ylim(0.0, 1.05)
  fig.savefig('testing.jpg', bbox_inches = 'tight')

# %%
@torch.no_grad()
def get_acc(model, dl, device = DEVICE):
    acc = []

    for X, y in dl:
        #y = y//2
        #one_hot_y = torch.zeros(X.shape[0], 5).to(device)
        #one_hot_y[[i for i in range(X.shape[0])], [k.item() for k in y]] = 1
        res = model.eval_forward(X)
        acc.append(res == y)

    acc = torch.cat(acc)
    acc = torch.sum(acc)/len(acc)

    return acc.item()

# %%
def embed_label(x, y):
    x_ = x.clone()
    x_[:, :10] *= 0
    x_[range(x.shape[0]), y] = 1
    return x_

# %%
class FFA_Linear(nn.Linear):
    def __init__(self, in_dim, out_dim, bias=True, device=DEVICE):
        super().__init__(in_dim, out_dim, bias, DEVICE)
        self.act = torch.nn.ReLU()
        self.opt = torch.optim.Adam(self.parameters(), lr=0.03)
        self.threshold = 2.0

    def eval_forward(self, x):
        x = x / (torch.norm(x, dim = 1, keepdim = True) + 1e-4)
        return self.act(x@self.weight.T + self.bias.unsqueeze(0))
    
    def train_forward(self, x_pos, x_neg):
        goodness_pos = self.eval_forward(x_pos).pow(2).mean(dim = 1)
        goodness_neg = self.eval_forward(x_neg).pow(2).mean(dim = 1)
        
        loss = torch.log(1 + torch.exp(torch.cat([-goodness_pos + self.threshold + 0.8, goodness_neg - self.threshold - 0.8]))).mean()
        self.opt.zero_grad()
        loss.backward()
        self.opt.step()
        return loss, self.eval_forward(x_pos).detach(), self.eval_forward(x_neg).detach()

# %%
class LeNet(nn.Module):

  def __init__(self, num_classes=10):
    super().__init__()
    self.fc1 = FFA_Linear(28*28, 1024)
    self.fc2 = FFA_Linear(1024, 1024)
    self.fc3 = FFA_Linear(1024, 1024)
    self.fc4 = FFA_Linear(1024, num_classes)

    self.num_classes = num_classes

  def train_forward(self, x_pos, x_neg):
    loss = 0
    new_loss, x_pos, x_neg = self.fc1.train_forward(x_pos, x_neg)
    loss += new_loss
    new_loss, x_pos, x_neg = self.fc2.train_forward(x_pos, x_neg)
    loss += new_loss
    new_loss, x_pos, x_neg = self.fc3.train_forward(x_pos, x_neg)
    loss += new_loss
    new_loss, x_pos, x_neg = self.fc4.train_forward(x_pos, x_neg)
    loss += new_loss
    return loss

  def eval_forward(self, x):
    goodness_per_label = []
    for label in range(self.num_classes):
      embed_x = embed_label(x, label)
      goodness = []
      embed_x = self.fc1.eval_forward(embed_x)
      goodness += [embed_x.pow(2).mean(1)]
      embed_x = self.fc2.eval_forward(embed_x)
      goodness += [embed_x.pow(2).mean(1)]
      embed_x = self.fc3.eval_forward(embed_x)
      goodness += [embed_x.pow(2).mean(1)]
      embed_x = self.fc4.eval_forward(embed_x)
      goodness += [embed_x.pow(2).mean(1)]
      goodness_per_label += [sum(goodness).unsqueeze(1)]
    goodness_per_label = torch.cat(goodness_per_label, dim = 1)
    return goodness_per_label.argmax(dim = 1)

# %%
def run_experiment(model, train_dl, valid_dl, test_dl, max_epochs = 20, device = DEVICE):
    itr = -1
    stats = {'train-loss' : [], 'valid-acc' : []}
    
    for epoch in range(max_epochs):
        for x, y in train_dl:
            itr += 1
            x_pos = embed_label(x, y)
            rnd = torch.randperm(x.size(0))
            x_neg = embed_label(x, y[rnd])
            loss = model.train_forward(x_pos,x_neg)
            stats['train-loss'].append((itr, loss))

            if itr % 100 == 0:
                valid_acc = get_acc(model, valid_dl)
                stats['valid-acc'].append((itr, valid_acc))
                s = f"{epoch}:{itr} [train] loss:{loss.item():.3f}, [valid] acc:{valid_acc:.3f}"
                print(s)
    test_acc = get_acc(model, test_dl)
    print(f"[test] acc:{test_acc:.3f}")

    return stats

# %%
model = LeNet().to(DEVICE)
print(count_parameters(model))

train_batch_size = 128
test_batch_size = 1024
train_dl, valid_dl, test_dl = get_mnist_dl(train_batch_size, test_batch_size, device = DEVICE)

max_epochs = 200
# Out:
# 2913290

# %%
stats = run_experiment(model, train_dl, valid_dl, test_dl, max_epochs)
print_stats(stats)
# Out:
# 0:0 [train] loss:5.835, [valid] acc:0.086
# 0:100 [train] loss:2.790, [valid] acc:0.117
# 0:200 [train] loss:2.724, [valid] acc:0.220
# 0:300 [train] loss:2.584, [valid] acc:0.333
# 0:400 [train] loss:2.378, [valid] acc:0.485
# 1:500 [train] loss:2.292, [valid] acc:0.752
# 1:600 [train] loss:2.279, [valid] acc:0.791
# 1:700 [train] loss:2.141, [valid] acc:0.833
# 1:800 [train] loss:2.112, [valid] acc:0.848
# 2:900 [train] loss:2.019, [valid] acc:0.847
# 2:1000 [train] loss:1.980, [valid] acc:0.859
# 2:1100 [train] loss:1.971, [valid] acc:0.853
# 2:1200 [train] loss:1.827, [valid] acc:0.875
# 3:1300 [train] loss:1.877, [valid] acc:0.880
# 3:1400 [train] loss:1.918, [valid] acc:0.886
# 3:1500 [train] loss:1.838, [valid] acc:0.896
# 3:1600 [train] loss:1.765, [valid] acc:0.912
# 3:1700 [train] loss:1.822, [valid] acc:0.903
# 4:1800 [train] loss:1.730, [valid] acc:0.903
# 4:1900 [train] loss:1.801, [valid] acc:0.912
# 4:2000 [train] loss:1.750, [valid] acc:0.902
# 4:2100 [train] loss:1.830, [valid] acc:0.913
# 5:2200 [train] loss:1.921, [valid] acc:0.917
# 5:2300 [train] loss:1.569, [valid] acc:0.909
# 5:2400 [train] loss:1.709, [valid] acc:0.911
# 5:2500 [train] loss:1.657, [valid] acc:0.917
# 6:2600 [train] loss:1.711, [valid] acc:0.922
# 6:2700 [train] loss:1.603, [valid] acc:0.912
# 6:2800 [train] loss:1.680, [valid] acc:0.926
# 6:2900 [train] loss:1.618, [valid] acc:0.922
# 6:3000 [train] loss:1.613, [valid] acc:0.927
# 7:3100 [train] loss:1.612, [valid] acc:0.928
# 7:3200 [train] loss:1.578, [valid] acc:0.920
# 7:3300 [train] loss:1.565, [valid] acc:0.932
# 7:3400 [train] loss:1.602, [valid] acc:0.913
# 8:3500 [train] loss:1.552, [valid] acc:0.929
# 8:3600 [train] loss:1.652, [valid] acc:0.938
# 8:3700 [train] loss:1.632, [valid] acc:0.936
# 8:3800 [train] loss:1.630, [valid] acc:0.940
# 9:3900 [train] loss:1.627, [valid] acc:0.932
# 9:4000 [train] loss:1.611, [valid] acc:0.937
# 9:4100 [train] loss:1.565, [valid] acc:0.936
# 9:4200 [train] loss:1.548, [valid] acc:0.938
# 10:4300 [train] loss:1.548, [valid] acc:0.944
# 10:4400 [train] loss:1.331, [valid] acc:0.941
# 10:4500 [train] loss:1.473, [valid] acc:0.943
# 10:4600 [train] loss:1.675, [valid] acc:0.941
# 10:4700 [train] loss:1.524, [valid] acc:0.948
# 11:4800 [train] loss:1.526, [valid] acc:0.942
# 11:4900 [train] loss:1.460, [valid] acc:0.936
# 11:5000 [train] loss:1.497, [valid] acc:0.948
# 11:5100 [train] loss:1.592, [valid] acc:0.949
# 12:5200 [train] loss:1.615, [valid] acc:0.947
# 12:5300 [train] loss:1.378, [valid] acc:0.951
# 12:5400 [train] loss:1.686, [valid] acc:0.947
# 12:5500 [train] loss:1.575, [valid] acc:0.948
# 13:5600 [train] loss:1.595, [valid] acc:0.942
# 13:5700 [train] loss:1.453, [valid] acc:0.948
# 13:5800 [train] loss:1.393, [valid] acc:0.950
# 13:5900 [train] loss:1.511, [valid] acc:0.950
# 13:6000 [train] loss:1.576, [valid] acc:0.948
# 14:6100 [train] loss:1.599, [valid] acc:0.951
# 14:6200 [train] loss:1.478, [valid] acc:0.951
# 14:6300 [train] loss:1.381, [valid] acc:0.950
# 14:6400 [train] loss:1.459, [valid] acc:0.953
# 15:6500 [train] loss:1.553, [valid] acc:0.953
# 15:6600 [train] loss:1.350, [valid] acc:0.954
# 15:6700 [train] loss:1.358, [valid] acc:0.955
# 15:6800 [train] loss:1.364, [valid] acc:0.950
# 16:6900 [train] loss:1.605, [valid] acc:0.951
# 16:7000 [train] loss:1.367, [valid] acc:0.950
# 16:7100 [train] loss:1.375, [valid] acc:0.948
# 16:7200 [train] loss:1.648, [valid] acc:0.949
# 16:7300 [train] loss:1.441, [valid] acc:0.950
# 17:7400 [train] loss:1.479, [valid] acc:0.953
# 17:7500 [train] loss:1.421, [valid] acc:0.949
# 17:7600 [train] loss:1.413, [valid] acc:0.953
# 17:7700 [train] loss:1.384, [valid] acc:0.953
# 18:7800 [train] loss:1.469, [valid] acc:0.955
# 18:7900 [train] loss:1.288, [valid] acc:0.954
# 18:8000 [train] loss:1.422, [valid] acc:0.955
# 18:8100 [train] loss:1.226, [valid] acc:0.954
# 19:8200 [train] loss:1.365, [valid] acc:0.955
# 19:8300 [train] loss:1.394, [valid] acc:0.958
# 19:8400 [train] loss:1.423, [valid] acc:0.952
# 19:8500 [train] loss:1.451, [valid] acc:0.952
# 20:8600 [train] loss:1.400, [valid] acc:0.957
# 20:8700 [train] loss:1.356, [valid] acc:0.958
# 20:8800 [train] loss:1.383, [valid] acc:0.954
# 20:8900 [train] loss:1.336, [valid] acc:0.954
# 20:9000 [train] loss:1.484, [valid] acc:0.955
# 21:9100 [train] loss:1.458, [valid] acc:0.956
# 21:9200 [train] loss:1.179, [valid] acc:0.954
# 21:9300 [train] loss:1.374, [valid] acc:0.954
# 21:9400 [train] loss:1.321, [valid] acc:0.950
# 22:9500 [train] loss:1.431, [valid] acc:0.956
# 22:9600 [train] loss:1.302, [valid] acc:0.956
# 22:9700 [train] loss:1.277, [valid] acc:0.956
# 22:9800 [train] loss:1.167, [valid] acc:0.956
# 23:9900 [train] loss:1.511, [valid] acc:0.956
# 23:10000 [train] loss:1.253, [valid] acc:0.953
# 23:10100 [train] loss:1.275, [valid] acc:0.956
# 23:10200 [train] loss:1.238, [valid] acc:0.954
# 23:10300 [train] loss:1.349, [valid] acc:0.956
# 24:10400 [train] loss:1.452, [valid] acc:0.956
# 24:10500 [train] loss:1.420, [valid] acc:0.952
# 24:10600 [train] loss:1.304, [valid] acc:0.955
# 24:10700 [train] loss:1.269, [valid] acc:0.955
# 25:10800 [train] loss:1.328, [valid] acc:0.953
# 25:10900 [train] loss:1.440, [valid] acc:0.958
# 25:11000 [train] loss:1.301, [valid] acc:0.957
# 25:11100 [train] loss:1.451, [valid] acc:0.955
# 26:11200 [train] loss:1.211, [valid] acc:0.953
# 26:11300 [train] loss:1.214, [valid] acc:0.958
# 26:11400 [train] loss:1.332, [valid] acc:0.956
# 26:11500 [train] loss:1.211, [valid] acc:0.954
# 26:11600 [train] loss:1.286, [valid] acc:0.955
# 27:11700 [train] loss:1.163, [valid] acc:0.955
# 27:11800 [train] loss:1.342, [valid] acc:0.959
# 27:11900 [train] loss:1.302, [valid] acc:0.955
# 27:12000 [train] loss:1.264, [valid] acc:0.954
# 28:12100 [train] loss:1.242, [valid] acc:0.959
# 28:12200 [train] loss:1.162, [valid] acc:0.956
# 28:12300 [train] loss:1.259, [valid] acc:0.958
# 28:12400 [train] loss:1.185, [valid] acc:0.958
# 29:12500 [train] loss:1.400, [valid] acc:0.954
# 29:12600 [train] loss:1.289, [valid] acc:0.955
# 29:12700 [train] loss:1.532, [valid] acc:0.957
# 29:12800 [train] loss:1.481, [valid] acc:0.953
# 30:12900 [train] loss:1.297, [valid] acc:0.959
# 30:13000 [train] loss:1.260, [valid] acc:0.954
# 30:13100 [train] loss:1.407, [valid] acc:0.954
# 30:13200 [train] loss:1.381, [valid] acc:0.949
# 30:13300 [train] loss:1.168, [valid] acc:0.958
# 31:13400 [train] loss:1.486, [valid] acc:0.957
# 31:13500 [train] loss:1.276, [valid] acc:0.957
# 31:13600 [train] loss:1.113, [valid] acc:0.954
# 31:13700 [train] loss:1.261, [valid] acc:0.956
# 32:13800 [train] loss:1.279, [valid] acc:0.959
# 32:13900 [train] loss:1.265, [valid] acc:0.954
# 32:14000 [train] loss:1.322, [valid] acc:0.958
# 32:14100 [train] loss:1.137, [valid] acc:0.957
# 33:14200 [train] loss:1.233, [valid] acc:0.957
# 33:14300 [train] loss:1.243, [valid] acc:0.957
# 33:14400 [train] loss:1.123, [valid] acc:0.956
# 33:14500 [train] loss:1.310, [valid] acc:0.959
# 33:14600 [train] loss:1.276, [valid] acc:0.958
# 34:14700 [train] loss:1.217, [valid] acc:0.957
# 34:14800 [train] loss:1.195, [valid] acc:0.960
# 34:14900 [train] loss:1.418, [valid] acc:0.953
# 34:15000 [train] loss:1.181, [valid] acc:0.958
# 35:15100 [train] loss:1.271, [valid] acc:0.956
# 35:15200 [train] loss:1.329, [valid] acc:0.958
# 35:15300 [train] loss:1.154, [valid] acc:0.956
# 35:15400 [train] loss:1.375, [valid] acc:0.956
# 36:15500 [train] loss:1.105, [valid] acc:0.959
# 36:15600 [train] loss:1.192, [valid] acc:0.955
# 36:15700 [train] loss:1.308, [valid] acc:0.956
# 36:15800 [train] loss:1.411, [valid] acc:0.957
# 36:15900 [train] loss:1.269, [valid] acc:0.958
# 37:16000 [train] loss:1.208, [valid] acc:0.959
# 37:16100 [train] loss:1.229, [valid] acc:0.957
# 37:16200 [train] loss:1.057, [valid] acc:0.955
# 37:16300 [train] loss:1.241, [valid] acc:0.957
# 38:16400 [train] loss:1.141, [valid] acc:0.956
# 38:16500 [train] loss:1.037, [valid] acc:0.956
# 38:16600 [train] loss:1.214, [valid] acc:0.950
# 38:16700 [train] loss:1.300, [valid] acc:0.959
# 39:16800 [train] loss:1.181, [valid] acc:0.959
# 39:16900 [train] loss:1.168, [valid] acc:0.958
# 39:17000 [train] loss:1.321, [valid] acc:0.957
# 39:17100 [train] loss:1.311, [valid] acc:0.961
# 40:17200 [train] loss:1.115, [valid] acc:0.959
# 40:17300 [train] loss:1.462, [valid] acc:0.960
# 40:17400 [train] loss:1.171, [valid] acc:0.959
# 40:17500 [train] loss:1.233, [valid] acc:0.957
# 40:17600 [train] loss:1.123, [valid] acc:0.960
# 41:17700 [train] loss:1.264, [valid] acc:0.958
# 41:17800 [train] loss:1.542, [valid] acc:0.957
# 41:17900 [train] loss:1.175, [valid] acc:0.957
# 41:18000 [train] loss:1.284, [valid] acc:0.960
# 42:18100 [train] loss:1.369, [valid] acc:0.954
# 42:18200 [train] loss:1.234, [valid] acc:0.957
# 42:18300 [train] loss:1.051, [valid] acc:0.958
# 42:18400 [train] loss:1.047, [valid] acc:0.959
# 43:18500 [train] loss:1.239, [valid] acc:0.956
# 43:18600 [train] loss:1.272, [valid] acc:0.958
# 43:18700 [train] loss:1.107, [valid] acc:0.958
# 43:18800 [train] loss:1.059, [valid] acc:0.958
# 43:18900 [train] loss:1.220, [valid] acc:0.958
# 44:19000 [train] loss:1.269, [valid] acc:0.960
# 44:19100 [train] loss:1.344, [valid] acc:0.959
# 44:19200 [train] loss:1.293, [valid] acc:0.956
# 44:19300 [train] loss:1.329, [valid] acc:0.962
# 45:19400 [train] loss:1.244, [valid] acc:0.960
# 45:19500 [train] loss:1.211, [valid] acc:0.960
# 45:19600 [train] loss:1.226, [valid] acc:0.958
# 45:19700 [train] loss:1.296, [valid] acc:0.958
# 46:19800 [train] loss:1.117, [valid] acc:0.956
# 46:19900 [train] loss:1.137, [valid] acc:0.960
# 46:20000 [train] loss:1.470, [valid] acc:0.956
# 46:20100 [train] loss:1.451, [valid] acc:0.959
# 46:20200 [train] loss:1.199, [valid] acc:0.958
# 47:20300 [train] loss:1.058, [valid] acc:0.956
# 47:20400 [train] loss:1.152, [valid] acc:0.959
# 47:20500 [train] loss:1.281, [valid] acc:0.957
# 47:20600 [train] loss:1.333, [valid] acc:0.959
# 48:20700 [train] loss:1.011, [valid] acc:0.961
# 48:20800 [train] loss:1.147, [valid] acc:0.959
# 48:20900 [train] loss:1.280, [valid] acc:0.962
# 48:21000 [train] loss:1.175, [valid] acc:0.963
# 49:21100 [train] loss:1.379, [valid] acc:0.957
# 49:21200 [train] loss:1.303, [valid] acc:0.958
# 49:21300 [train] loss:1.345, [valid] acc:0.959
# 49:21400 [train] loss:1.209, [valid] acc:0.965
# 50:21500 [train] loss:1.438, [valid] acc:0.962
# 50:21600 [train] loss:1.345, [valid] acc:0.961
# 50:21700 [train] loss:1.110, [valid] acc:0.963
# 50:21800 [train] loss:1.282, [valid] acc:0.965
# 50:21900 [train] loss:1.198, [valid] acc:0.962
# 51:22000 [train] loss:1.205, [valid] acc:0.962
# 51:22100 [train] loss:1.098, [valid] acc:0.961
# 51:22200 [train] loss:1.362, [valid] acc:0.958
# 51:22300 [train] loss:1.198, [valid] acc:0.965
# 52:22400 [train] loss:1.202, [valid] acc:0.961
# 52:22500 [train] loss:1.343, [valid] acc:0.961
# 52:22600 [train] loss:1.392, [valid] acc:0.962
# 52:22700 [train] loss:1.249, [valid] acc:0.962
# 53:22800 [train] loss:1.328, [valid] acc:0.964
# 53:22900 [train] loss:1.199, [valid] acc:0.962
# 53:23000 [train] loss:1.102, [valid] acc:0.961
# 53:23100 [train] loss:1.199, [valid] acc:0.962
# 53:23200 [train] loss:1.154, [valid] acc:0.964
# 54:23300 [train] loss:1.046, [valid] acc:0.964
# 54:23400 [train] loss:1.041, [valid] acc:0.958
# 54:23500 [train] loss:1.280, [valid] acc:0.964
# 54:23600 [train] loss:1.131, [valid] acc:0.965
# 55:23700 [train] loss:0.888, [valid] acc:0.963
# 55:23800 [train] loss:1.233, [valid] acc:0.962
# 55:23900 [train] loss:1.121, [valid] acc:0.963
# 55:24000 [train] loss:1.235, [valid] acc:0.964
# 56:24100 [train] loss:1.107, [valid] acc:0.959
# 56:24200 [train] loss:1.187, [valid] acc:0.966
# 56:24300 [train] loss:1.112, [valid] acc:0.961
# 56:24400 [train] loss:1.175, [valid] acc:0.964
# 56:24500 [train] loss:1.253, [valid] acc:0.964
# 57:24600 [train] loss:1.285, [valid] acc:0.964
# 57:24700 [train] loss:1.088, [valid] acc:0.961
# 57:24800 [train] loss:0.998, [valid] acc:0.960
# 57:24900 [train] loss:1.051, [valid] acc:0.964
# 58:25000 [train] loss:1.263, [valid] acc:0.960
# 58:25100 [train] loss:1.265, [valid] acc:0.962
# 58:25200 [train] loss:1.243, [valid] acc:0.963
# 58:25300 [train] loss:1.199, [valid] acc:0.961
# 59:25400 [train] loss:1.211, [valid] acc:0.963
# 59:25500 [train] loss:1.319, [valid] acc:0.962
# 59:25600 [train] loss:1.151, [valid] acc:0.963
# 59:25700 [train] loss:1.019, [valid] acc:0.964
# 60:25800 [train] loss:1.200, [valid] acc:0.960
# 60:25900 [train] loss:1.567, [valid] acc:0.965
# 60:26000 [train] loss:1.295, [valid] acc:0.963
# 60:26100 [train] loss:0.988, [valid] acc:0.962
# 60:26200 [train] loss:1.113, [valid] acc:0.959
# 61:26300 [train] loss:1.211, [valid] acc:0.964
# 61:26400 [train] loss:1.216, [valid] acc:0.962
# 61:26500 [train] loss:1.208, [valid] acc:0.964
# 61:26600 [train] loss:1.189, [valid] acc:0.962
# 62:26700 [train] loss:1.061, [valid] acc:0.965
# 62:26800 [train] loss:1.181, [valid] acc:0.963
# 62:26900 [train] loss:1.180, [valid] acc:0.960
# 62:27000 [train] loss:0.980, [valid] acc:0.967
# 63:27100 [train] loss:1.151, [valid] acc:0.960
# 63:27200 [train] loss:1.170, [valid] acc:0.964
# 63:27300 [train] loss:1.282, [valid] acc:0.962
# 63:27400 [train] loss:1.255, [valid] acc:0.963
# 63:27500 [train] loss:1.259, [valid] acc:0.964
# 64:27600 [train] loss:1.155, [valid] acc:0.963
# 64:27700 [train] loss:1.179, [valid] acc:0.959
# 64:27800 [train] loss:1.030, [valid] acc:0.960
# 64:27900 [train] loss:1.296, [valid] acc:0.962
# 65:28000 [train] loss:1.121, [valid] acc:0.963
# 65:28100 [train] loss:1.312, [valid] acc:0.967
# 65:28200 [train] loss:1.141, [valid] acc:0.965
# 65:28300 [train] loss:1.092, [valid] acc:0.964
# 66:28400 [train] loss:1.235, [valid] acc:0.960
# 66:28500 [train] loss:1.065, [valid] acc:0.962
# 66:28600 [train] loss:1.298, [valid] acc:0.964
# 66:28700 [train] loss:1.229, [valid] acc:0.963
# 66:28800 [train] loss:1.291, [valid] acc:0.965
# 67:28900 [train] loss:0.968, [valid] acc:0.960
# 67:29000 [train] loss:1.169, [valid] acc:0.964
# 67:29100 [train] loss:1.310, [valid] acc:0.964
# 67:29200 [train] loss:1.194, [valid] acc:0.961
# 68:29300 [train] loss:1.030, [valid] acc:0.961
# 68:29400 [train] loss:0.974, [valid] acc:0.963
# 68:29500 [train] loss:1.160, [valid] acc:0.963
# 68:29600 [train] loss:1.148, [valid] acc:0.965
# 69:29700 [train] loss:1.124, [valid] acc:0.963
# 69:29800 [train] loss:0.994, [valid] acc:0.962
# 69:29900 [train] loss:1.079, [valid] acc:0.964
# 69:30000 [train] loss:0.943, [valid] acc:0.965
# 70:30100 [train] loss:1.035, [valid] acc:0.964
# 70:30200 [train] loss:1.238, [valid] acc:0.964
# 70:30300 [train] loss:1.190, [valid] acc:0.962
# 70:30400 [train] loss:1.187, [valid] acc:0.962
# 70:30500 [train] loss:1.010, [valid] acc:0.962
# 71:30600 [train] loss:1.117, [valid] acc:0.964
# 71:30700 [train] loss:0.987, [valid] acc:0.960
# 71:30800 [train] loss:1.147, [valid] acc:0.958
# 71:30900 [train] loss:1.087, [valid] acc:0.962
# 72:31000 [train] loss:1.034, [valid] acc:0.965
# 72:31100 [train] loss:1.220, [valid] acc:0.963
# 72:31200 [train] loss:1.022, [valid] acc:0.963
# 72:31300 [train] loss:1.325, [valid] acc:0.963
# 73:31400 [train] loss:1.076, [valid] acc:0.965
# 73:31500 [train] loss:1.007, [valid] acc:0.964
# 73:31600 [train] loss:1.145, [valid] acc:0.965
# 73:31700 [train] loss:1.170, [valid] acc:0.965
# 73:31800 [train] loss:1.031, [valid] acc:0.965
# 74:31900 [train] loss:1.269, [valid] acc:0.964
# 74:32000 [train] loss:1.179, [valid] acc:0.965
# 74:32100 [train] loss:1.149, [valid] acc:0.965
# 74:32200 [train] loss:1.171, [valid] acc:0.965
# 75:32300 [train] loss:1.168, [valid] acc:0.965
# 75:32400 [train] loss:1.146, [valid] acc:0.965
# 75:32500 [train] loss:1.185, [valid] acc:0.965
# 75:32600 [train] loss:0.984, [valid] acc:0.964
# 76:32700 [train] loss:1.086, [valid] acc:0.966
# 76:32800 [train] loss:1.199, [valid] acc:0.965
# 76:32900 [train] loss:1.202, [valid] acc:0.966
# 76:33000 [train] loss:1.150, [valid] acc:0.968
# 76:33100 [train] loss:1.137, [valid] acc:0.966
# 77:33200 [train] loss:1.178, [valid] acc:0.966
# 77:33300 [train] loss:1.135, [valid] acc:0.968
# 77:33400 [train] loss:0.994, [valid] acc:0.967
# 77:33500 [train] loss:1.208, [valid] acc:0.964
# 78:33600 [train] loss:1.118, [valid] acc:0.967
# 78:33700 [train] loss:0.864, [valid] acc:0.966
# 78:33800 [train] loss:1.288, [valid] acc:0.966
# 78:33900 [train] loss:1.217, [valid] acc:0.969
# 79:34000 [train] loss:1.247, [valid] acc:0.965
# 79:34100 [train] loss:1.065, [valid] acc:0.968
# 79:34200 [train] loss:1.132, [valid] acc:0.966
# 79:34300 [train] loss:1.117, [valid] acc:0.965
# 80:34400 [train] loss:0.952, [valid] acc:0.968
# 80:34500 [train] loss:0.949, [valid] acc:0.968
# 80:34600 [train] loss:1.329, [valid] acc:0.962
# 80:34700 [train] loss:1.077, [valid] acc:0.967
# 80:34800 [train] loss:0.971, [valid] acc:0.963
# 81:34900 [train] loss:1.219, [valid] acc:0.965
# 81:35000 [train] loss:1.303, [valid] acc:0.966
# 81:35100 [train] loss:1.083, [valid] acc:0.965
# 81:35200 [train] loss:1.019, [valid] acc:0.966
# 82:35300 [train] loss:1.199, [valid] acc:0.968
# 82:35400 [train] loss:1.091, [valid] acc:0.965
# 82:35500 [train] loss:0.931, [valid] acc:0.965
# 82:35600 [train] loss:0.967, [valid] acc:0.967
# 83:35700 [train] loss:1.153, [valid] acc:0.966
# 83:35800 [train] loss:1.017, [valid] acc:0.969
# 83:35900 [train] loss:0.940, [valid] acc:0.964
# 83:36000 [train] loss:1.054, [valid] acc:0.967
# 83:36100 [train] loss:1.005, [valid] acc:0.965
# 84:36200 [train] loss:1.158, [valid] acc:0.967
# 84:36300 [train] loss:1.177, [valid] acc:0.966
# 84:36400 [train] loss:0.931, [valid] acc:0.964
# 84:36500 [train] loss:1.087, [valid] acc:0.967
# 85:36600 [train] loss:1.115, [valid] acc:0.965
# 85:36700 [train] loss:1.119, [valid] acc:0.965
# 85:36800 [train] loss:1.041, [valid] acc:0.964
# 85:36900 [train] loss:1.098, [valid] acc:0.968
# 86:37000 [train] loss:1.128, [valid] acc:0.965
# 86:37100 [train] loss:0.857, [valid] acc:0.968
# 86:37200 [train] loss:0.972, [valid] acc:0.966
# 86:37300 [train] loss:1.074, [valid] acc:0.968
# 86:37400 [train] loss:1.159, [valid] acc:0.964
# 87:37500 [train] loss:1.152, [valid] acc:0.965
# 87:37600 [train] loss:1.030, [valid] acc:0.965
# 87:37700 [train] loss:1.040, [valid] acc:0.965
# 87:37800 [train] loss:1.071, [valid] acc:0.966
# 88:37900 [train] loss:1.124, [valid] acc:0.967
# 88:38000 [train] loss:1.093, [valid] acc:0.969
# 88:38100 [train] loss:1.244, [valid] acc:0.968
# 88:38200 [train] loss:1.122, [valid] acc:0.968
# 89:38300 [train] loss:1.067, [valid] acc:0.965
# 89:38400 [train] loss:1.200, [valid] acc:0.967
# 89:38500 [train] loss:0.945, [valid] acc:0.967
# 89:38600 [train] loss:1.117, [valid] acc:0.966
# 90:38700 [train] loss:0.926, [valid] acc:0.969
# 90:38800 [train] loss:1.157, [valid] acc:0.965
# 90:38900 [train] loss:0.925, [valid] acc:0.967
# 90:39000 [train] loss:1.070, [valid] acc:0.965
# 90:39100 [train] loss:1.204, [valid] acc:0.966
# 91:39200 [train] loss:0.873, [valid] acc:0.962
# 91:39300 [train] loss:1.011, [valid] acc:0.964
# 91:39400 [train] loss:0.982, [valid] acc:0.966
# 91:39500 [train] loss:1.188, [valid] acc:0.964
# 92:39600 [train] loss:1.189, [valid] acc:0.968
# 92:39700 [train] loss:0.927, [valid] acc:0.968
# 92:39800 [train] loss:0.912, [valid] acc:0.967
# 92:39900 [train] loss:0.817, [valid] acc:0.965
# 93:40000 [train] loss:0.983, [valid] acc:0.969
# 93:40100 [train] loss:1.157, [valid] acc:0.965
# 93:40200 [train] loss:1.059, [valid] acc:0.967
# 93:40300 [train] loss:1.105, [valid] acc:0.968
# 93:40400 [train] loss:0.983, [valid] acc:0.967
# 94:40500 [train] loss:1.071, [valid] acc:0.966
# 94:40600 [train] loss:1.273, [valid] acc:0.966
# 94:40700 [train] loss:1.205, [valid] acc:0.968
# 94:40800 [train] loss:1.220, [valid] acc:0.968
# 95:40900 [train] loss:1.050, [valid] acc:0.968
# 95:41000 [train] loss:1.156, [valid] acc:0.968
# 95:41100 [train] loss:0.818, [valid] acc:0.969
# 95:41200 [train] loss:1.393, [valid] acc:0.968
# 96:41300 [train] loss:1.027, [valid] acc:0.969
# 96:41400 [train] loss:1.187, [valid] acc:0.970
# 96:41500 [train] loss:0.958, [valid] acc:0.968
# 96:41600 [train] loss:1.156, [valid] acc:0.969
# 96:41700 [train] loss:1.086, [valid] acc:0.966
# 97:41800 [train] loss:1.225, [valid] acc:0.965
# 97:41900 [train] loss:1.357, [valid] acc:0.968
# 97:42000 [train] loss:1.265, [valid] acc:0.967
# 97:42100 [train] loss:1.005, [valid] acc:0.967
# 98:42200 [train] loss:1.066, [valid] acc:0.967
# 98:42300 [train] loss:1.087, [valid] acc:0.962
# 98:42400 [train] loss:1.060, [valid] acc:0.965
# 98:42500 [train] loss:0.925, [valid] acc:0.965
# 99:42600 [train] loss:1.129, [valid] acc:0.971
# 99:42700 [train] loss:1.124, [valid] acc:0.967
# 99:42800 [train] loss:1.068, [valid] acc:0.967
# 99:42900 [train] loss:1.140, [valid] acc:0.968
# 100:43000 [train] loss:1.250, [valid] acc:0.966
# 100:43100 [train] loss:1.043, [valid] acc:0.968
# 100:43200 [train] loss:1.312, [valid] acc:0.969
# 100:43300 [train] loss:0.975, [valid] acc:0.967
# 100:43400 [train] loss:1.111, [valid] acc:0.968
# 101:43500 [train] loss:1.221, [valid] acc:0.969
# 101:43600 [train] loss:0.913, [valid] acc:0.965
# 101:43700 [train] loss:1.100, [valid] acc:0.970
# 101:43800 [train] loss:1.108, [valid] acc:0.965
# 102:43900 [train] loss:1.079, [valid] acc:0.962
# 102:44000 [train] loss:1.037, [valid] acc:0.967
# 102:44100 [train] loss:0.922, [valid] acc:0.969
# 102:44200 [train] loss:1.005, [valid] acc:0.966
# 103:44300 [train] loss:0.952, [valid] acc:0.965
# 103:44400 [train] loss:1.354, [valid] acc:0.967
# 103:44500 [train] loss:1.107, [valid] acc:0.970
# 103:44600 [train] loss:0.955, [valid] acc:0.965
# 103:44700 [train] loss:1.063, [valid] acc:0.967
# 104:44800 [train] loss:0.986, [valid] acc:0.969
# 104:44900 [train] loss:1.064, [valid] acc:0.967
# 104:45000 [train] loss:1.003, [valid] acc:0.966
# 104:45100 [train] loss:1.197, [valid] acc:0.965
# 105:45200 [train] loss:1.066, [valid] acc:0.966
# 105:45300 [train] loss:1.164, [valid] acc:0.969
# 105:45400 [train] loss:1.018, [valid] acc:0.966
# 105:45500 [train] loss:1.012, [valid] acc:0.969
# 106:45600 [train] loss:1.177, [valid] acc:0.966
# 106:45700 [train] loss:1.141, [valid] acc:0.966
# 106:45800 [train] loss:1.094, [valid] acc:0.967
# 106:45900 [train] loss:1.062, [valid] acc:0.967
# 106:46000 [train] loss:1.086, [valid] acc:0.966
# 107:46100 [train] loss:1.093, [valid] acc:0.970
# 107:46200 [train] loss:1.067, [valid] acc:0.970
# 107:46300 [train] loss:0.954, [valid] acc:0.968
# 107:46400 [train] loss:1.068, [valid] acc:0.964
# 108:46500 [train] loss:1.205, [valid] acc:0.969
# 108:46600 [train] loss:1.029, [valid] acc:0.968
# 108:46700 [train] loss:1.103, [valid] acc:0.972
# 108:46800 [train] loss:0.933, [valid] acc:0.969
# 109:46900 [train] loss:0.880, [valid] acc:0.969
# 109:47000 [train] loss:0.950, [valid] acc:0.967
# 109:47100 [train] loss:1.149, [valid] acc:0.966
# 109:47200 [train] loss:1.102, [valid] acc:0.967
# 110:47300 [train] loss:0.960, [valid] acc:0.969
# 110:47400 [train] loss:0.984, [valid] acc:0.972
# 110:47500 [train] loss:1.238, [valid] acc:0.967
# 110:47600 [train] loss:1.077, [valid] acc:0.970
# 110:47700 [train] loss:0.992, [valid] acc:0.969
# 111:47800 [train] loss:1.022, [valid] acc:0.968
# 111:47900 [train] loss:1.169, [valid] acc:0.968
# 111:48000 [train] loss:0.987, [valid] acc:0.966
# 111:48100 [train] loss:1.065, [valid] acc:0.966
# 112:48200 [train] loss:1.052, [valid] acc:0.970
# 112:48300 [train] loss:1.057, [valid] acc:0.969
# 112:48400 [train] loss:1.293, [valid] acc:0.965
# 112:48500 [train] loss:1.058, [valid] acc:0.966
# 113:48600 [train] loss:1.097, [valid] acc:0.967
# 113:48700 [train] loss:1.008, [valid] acc:0.965
# 113:48800 [train] loss:1.163, [valid] acc:0.965
# 113:48900 [train] loss:1.386, [valid] acc:0.970
# 113:49000 [train] loss:0.874, [valid] acc:0.967
# 114:49100 [train] loss:1.106, [valid] acc:0.972
# 114:49200 [train] loss:0.961, [valid] acc:0.970
# 114:49300 [train] loss:1.269, [valid] acc:0.970
# 114:49400 [train] loss:1.109, [valid] acc:0.967
# 115:49500 [train] loss:1.073, [valid] acc:0.969
# 115:49600 [train] loss:1.139, [valid] acc:0.969
# 115:49700 [train] loss:1.083, [valid] acc:0.967
# 115:49800 [train] loss:1.066, [valid] acc:0.969
# 116:49900 [train] loss:0.966, [valid] acc:0.966
# 116:50000 [train] loss:1.082, [valid] acc:0.965
# 116:50100 [train] loss:1.148, [valid] acc:0.970
# 116:50200 [train] loss:1.065, [valid] acc:0.969
# 116:50300 [train] loss:1.061, [valid] acc:0.970
# 117:50400 [train] loss:1.009, [valid] acc:0.971
# 117:50500 [train] loss:0.911, [valid] acc:0.969
# 117:50600 [train] loss:1.331, [valid] acc:0.969
# 117:50700 [train] loss:1.230, [valid] acc:0.972
# 118:50800 [train] loss:1.318, [valid] acc:0.970
# 118:50900 [train] loss:0.940, [valid] acc:0.969
# 118:51000 [train] loss:1.101, [valid] acc:0.970
# 118:51100 [train] loss:0.962, [valid] acc:0.971
# 119:51200 [train] loss:1.007, [valid] acc:0.972
# 119:51300 [train] loss:1.089, [valid] acc:0.970
# 119:51400 [train] loss:1.068, [valid] acc:0.972
# 119:51500 [train] loss:0.894, [valid] acc:0.969
# 120:51600 [train] loss:0.935, [valid] acc:0.971
# 120:51700 [train] loss:1.156, [valid] acc:0.970
# 120:51800 [train] loss:1.172, [valid] acc:0.970
# 120:51900 [train] loss:1.194, [valid] acc:0.970
# 120:52000 [train] loss:0.854, [valid] acc:0.967
# 121:52100 [train] loss:1.289, [valid] acc:0.972
# 121:52200 [train] loss:0.847, [valid] acc:0.966
# 121:52300 [train] loss:1.123, [valid] acc:0.968
# 121:52400 [train] loss:0.961, [valid] acc:0.971
# 122:52500 [train] loss:1.181, [valid] acc:0.968
# 122:52600 [train] loss:0.946, [valid] acc:0.970
# 122:52700 [train] loss:0.932, [valid] acc:0.971
# 122:52800 [train] loss:1.213, [valid] acc:0.969
# 123:52900 [train] loss:0.989, [valid] acc:0.972
# 123:53000 [train] loss:1.346, [valid] acc:0.972
# 123:53100 [train] loss:0.842, [valid] acc:0.969
# 123:53200 [train] loss:1.143, [valid] acc:0.972
# 123:53300 [train] loss:1.022, [valid] acc:0.969
# 124:53400 [train] loss:1.168, [valid] acc:0.969
# 124:53500 [train] loss:1.129, [valid] acc:0.967
# 124:53600 [train] loss:1.103, [valid] acc:0.970
# 124:53700 [train] loss:1.020, [valid] acc:0.969
# 125:53800 [train] loss:1.183, [valid] acc:0.970
# 125:53900 [train] loss:1.077, [valid] acc:0.970
# 125:54000 [train] loss:1.173, [valid] acc:0.969
# 125:54100 [train] loss:1.141, [valid] acc:0.971
# 126:54200 [train] loss:1.234, [valid] acc:0.968
# 126:54300 [train] loss:1.205, [valid] acc:0.971
# 126:54400 [train] loss:0.951, [valid] acc:0.967
# 126:54500 [train] loss:0.903, [valid] acc:0.970
# 126:54600 [train] loss:1.243, [valid] acc:0.970
# 127:54700 [train] loss:1.089, [valid] acc:0.968
# 127:54800 [train] loss:1.005, [valid] acc:0.970
# 127:54900 [train] loss:1.008, [valid] acc:0.971
# 127:55000 [train] loss:0.988, [valid] acc:0.971
# 128:55100 [train] loss:0.936, [valid] acc:0.968
# 128:55200 [train] loss:0.974, [valid] acc:0.973
# 128:55300 [train] loss:1.016, [valid] acc:0.970
# 128:55400 [train] loss:1.099, [valid] acc:0.968
# 129:55500 [train] loss:0.800, [valid] acc:0.970
# 129:55600 [train] loss:1.069, [valid] acc:0.973
# 129:55700 [train] loss:1.071, [valid] acc:0.971
# 129:55800 [train] loss:1.029, [valid] acc:0.968
# 130:55900 [train] loss:0.899, [valid] acc:0.971
# 130:56000 [train] loss:1.063, [valid] acc:0.973
# 130:56100 [train] loss:0.986, [valid] acc:0.972
# 130:56200 [train] loss:1.218, [valid] acc:0.971
# 130:56300 [train] loss:1.143, [valid] acc:0.970
# 131:56400 [train] loss:1.145, [valid] acc:0.970
# 131:56500 [train] loss:0.823, [valid] acc:0.972
# 131:56600 [train] loss:0.921, [valid] acc:0.973
# 131:56700 [train] loss:1.092, [valid] acc:0.971
# 132:56800 [train] loss:1.076, [valid] acc:0.970
# 132:56900 [train] loss:1.193, [valid] acc:0.972
# 132:57000 [train] loss:0.986, [valid] acc:0.973
# 132:57100 [train] loss:1.007, [valid] acc:0.969
# 133:57200 [train] loss:1.121, [valid] acc:0.971
# 133:57300 [train] loss:1.203, [valid] acc:0.972
# 133:57400 [train] loss:1.122, [valid] acc:0.972
# 133:57500 [train] loss:1.115, [valid] acc:0.971
# 133:57600 [train] loss:0.926, [valid] acc:0.973
# 134:57700 [train] loss:0.978, [valid] acc:0.974
# 134:57800 [train] loss:1.103, [valid] acc:0.970
# 134:57900 [train] loss:1.124, [valid] acc:0.972
# 134:58000 [train] loss:1.024, [valid] acc:0.973
# 135:58100 [train] loss:0.989, [valid] acc:0.972
# 135:58200 [train] loss:1.128, [valid] acc:0.971
# 135:58300 [train] loss:1.139, [valid] acc:0.970
# 135:58400 [train] loss:1.015, [valid] acc:0.970
# 136:58500 [train] loss:1.001, [valid] acc:0.973
# 136:58600 [train] loss:1.123, [valid] acc:0.974
# 136:58700 [train] loss:0.974, [valid] acc:0.975
# 136:58800 [train] loss:0.916, [valid] acc:0.972
# 136:58900 [train] loss:0.928, [valid] acc:0.973
# 137:59000 [train] loss:1.214, [valid] acc:0.972
# 137:59100 [train] loss:0.909, [valid] acc:0.973
# 137:59200 [train] loss:1.111, [valid] acc:0.972
# 137:59300 [train] loss:0.888, [valid] acc:0.971
# 138:59400 [train] loss:0.943, [valid] acc:0.970
# 138:59500 [train] loss:1.130, [valid] acc:0.968
# 138:59600 [train] loss:0.998, [valid] acc:0.972
# 138:59700 [train] loss:1.031, [valid] acc:0.972
# 139:59800 [train] loss:1.197, [valid] acc:0.974
# 139:59900 [train] loss:0.995, [valid] acc:0.968
# 139:60000 [train] loss:0.984, [valid] acc:0.972
# 139:60100 [train] loss:1.085, [valid] acc:0.973
# 140:60200 [train] loss:0.912, [valid] acc:0.968
# 140:60300 [train] loss:1.036, [valid] acc:0.972
# 140:60400 [train] loss:1.163, [valid] acc:0.972
# 140:60500 [train] loss:1.126, [valid] acc:0.974
# 140:60600 [train] loss:1.197, [valid] acc:0.974
# 141:60700 [train] loss:1.251, [valid] acc:0.971
# 141:60800 [train] loss:1.228, [valid] acc:0.975
# 141:60900 [train] loss:0.879, [valid] acc:0.973
# 141:61000 [train] loss:0.977, [valid] acc:0.972
# 142:61100 [train] loss:1.057, [valid] acc:0.969
# 142:61200 [train] loss:1.077, [valid] acc:0.973
# 142:61300 [train] loss:0.967, [valid] acc:0.974
# 142:61400 [train] loss:0.987, [valid] acc:0.970
# 143:61500 [train] loss:1.076, [valid] acc:0.971
# 143:61600 [train] loss:1.157, [valid] acc:0.971
# 143:61700 [train] loss:0.956, [valid] acc:0.970
# 143:61800 [train] loss:1.131, [valid] acc:0.969
# 143:61900 [train] loss:0.997, [valid] acc:0.967
# 144:62000 [train] loss:1.026, [valid] acc:0.969
# 144:62100 [train] loss:0.853, [valid] acc:0.971
# 144:62200 [train] loss:1.282, [valid] acc:0.972
# 144:62300 [train] loss:1.052, [valid] acc:0.969
# 145:62400 [train] loss:0.925, [valid] acc:0.971
# 145:62500 [train] loss:0.988, [valid] acc:0.972
# 145:62600 [train] loss:1.033, [valid] acc:0.971
# 145:62700 [train] loss:1.116, [valid] acc:0.968
# 146:62800 [train] loss:1.065, [valid] acc:0.970
# 146:62900 [train] loss:1.173, [valid] acc:0.970
# 146:63000 [train] loss:0.833, [valid] acc:0.971
# 146:63100 [train] loss:1.122, [valid] acc:0.971
# 146:63200 [train] loss:1.035, [valid] acc:0.972
# 147:63300 [train] loss:1.081, [valid] acc:0.971
# 147:63400 [train] loss:0.898, [valid] acc:0.974
# 147:63500 [train] loss:1.094, [valid] acc:0.974
# 147:63600 [train] loss:1.004, [valid] acc:0.973
# 148:63700 [train] loss:1.190, [valid] acc:0.972
# 148:63800 [train] loss:0.998, [valid] acc:0.971
# 148:63900 [train] loss:0.916, [valid] acc:0.970
# 148:64000 [train] loss:1.213, [valid] acc:0.971
# 149:64100 [train] loss:1.203, [valid] acc:0.970
# 149:64200 [train] loss:1.075, [valid] acc:0.973
# 149:64300 [train] loss:1.088, [valid] acc:0.971
# 149:64400 [train] loss:1.102, [valid] acc:0.971
# 150:64500 [train] loss:1.290, [valid] acc:0.972
# 150:64600 [train] loss:1.039, [valid] acc:0.972
# 150:64700 [train] loss:1.189, [valid] acc:0.974
# 150:64800 [train] loss:0.827, [valid] acc:0.973
# 150:64900 [train] loss:1.067, [valid] acc:0.970
# 151:65000 [train] loss:1.031, [valid] acc:0.971
# 151:65100 [train] loss:1.039, [valid] acc:0.970
# 151:65200 [train] loss:1.062, [valid] acc:0.970
# 151:65300 [train] loss:0.968, [valid] acc:0.973
# 152:65400 [train] loss:0.757, [valid] acc:0.974
# 152:65500 [train] loss:0.981, [valid] acc:0.972
# 152:65600 [train] loss:0.993, [valid] acc:0.973
# 152:65700 [train] loss:1.045, [valid] acc:0.973
# 153:65800 [train] loss:1.050, [valid] acc:0.970
# 153:65900 [train] loss:0.976, [valid] acc:0.973
# 153:66000 [train] loss:0.854, [valid] acc:0.969
# 153:66100 [train] loss:1.004, [valid] acc:0.973
# 153:66200 [train] loss:1.033, [valid] acc:0.971
# 154:66300 [train] loss:0.810, [valid] acc:0.973
# 154:66400 [train] loss:1.091, [valid] acc:0.970
# 154:66500 [train] loss:1.063, [valid] acc:0.972
# 154:66600 [train] loss:1.004, [valid] acc:0.973
# 155:66700 [train] loss:0.944, [valid] acc:0.973
# 155:66800 [train] loss:0.915, [valid] acc:0.973
# 155:66900 [train] loss:1.064, [valid] acc:0.973
# 155:67000 [train] loss:1.088, [valid] acc:0.973
# 156:67100 [train] loss:0.741, [valid] acc:0.972
# 156:67200 [train] loss:1.203, [valid] acc:0.974
# 156:67300 [train] loss:1.226, [valid] acc:0.973
# 156:67400 [train] loss:0.833, [valid] acc:0.973
# 156:67500 [train] loss:0.943, [valid] acc:0.973
# 157:67600 [train] loss:1.273, [valid] acc:0.972
# 157:67700 [train] loss:1.007, [valid] acc:0.971
# 157:67800 [train] loss:1.081, [valid] acc:0.971
# 157:67900 [train] loss:1.027, [valid] acc:0.971
# 158:68000 [train] loss:0.937, [valid] acc:0.970
# 158:68100 [train] loss:1.029, [valid] acc:0.972
# 158:68200 [train] loss:0.969, [valid] acc:0.971
# 158:68300 [train] loss:1.009, [valid] acc:0.971
# 159:68400 [train] loss:0.985, [valid] acc:0.973
# 159:68500 [train] loss:0.948, [valid] acc:0.972
# 159:68600 [train] loss:0.975, [valid] acc:0.971
# 159:68700 [train] loss:1.183, [valid] acc:0.971
# 160:68800 [train] loss:1.065, [valid] acc:0.973
# 160:68900 [train] loss:1.280, [valid] acc:0.972
# 160:69000 [train] loss:1.129, [valid] acc:0.974
# 160:69100 [train] loss:1.040, [valid] acc:0.970
# 160:69200 [train] loss:1.121, [valid] acc:0.972
# 161:69300 [train] loss:1.020, [valid] acc:0.972
# 161:69400 [train] loss:1.004, [valid] acc:0.972
# 161:69500 [train] loss:1.000, [valid] acc:0.972
# 161:69600 [train] loss:0.996, [valid] acc:0.973
# 162:69700 [train] loss:1.026, [valid] acc:0.972
# 162:69800 [train] loss:1.187, [valid] acc:0.970
# 162:69900 [train] loss:1.267, [valid] acc:0.971
# 162:70000 [train] loss:1.099, [valid] acc:0.972
# 163:70100 [train] loss:0.870, [valid] acc:0.974
# 163:70200 [train] loss:0.950, [valid] acc:0.969
# 163:70300 [train] loss:1.057, [valid] acc:0.972
# 163:70400 [train] loss:0.894, [valid] acc:0.973
# 163:70500 [train] loss:0.801, [valid] acc:0.972
# 164:70600 [train] loss:1.159, [valid] acc:0.973
# 164:70700 [train] loss:0.971, [valid] acc:0.975
# 164:70800 [train] loss:1.117, [valid] acc:0.973
# 164:70900 [train] loss:1.180, [valid] acc:0.971
# 165:71000 [train] loss:0.931, [valid] acc:0.972
# 165:71100 [train] loss:0.900, [valid] acc:0.969
# 165:71200 [train] loss:1.023, [valid] acc:0.972
# 165:71300 [train] loss:1.268, [valid] acc:0.972
# 166:71400 [train] loss:1.122, [valid] acc:0.973
# 166:71500 [train] loss:1.090, [valid] acc:0.967
# 166:71600 [train] loss:0.893, [valid] acc:0.972
# 166:71700 [train] loss:1.089, [valid] acc:0.970
# 166:71800 [train] loss:1.117, [valid] acc:0.970
# 167:71900 [train] loss:0.971, [valid] acc:0.971
# 167:72000 [train] loss:1.161, [valid] acc:0.972
# 167:72100 [train] loss:0.911, [valid] acc:0.972
# 167:72200 [train] loss:0.969, [valid] acc:0.971
# 168:72300 [train] loss:1.087, [valid] acc:0.971
# 168:72400 [train] loss:0.993, [valid] acc:0.972
# 168:72500 [train] loss:1.043, [valid] acc:0.969
# 168:72600 [train] loss:0.756, [valid] acc:0.974
# 169:72700 [train] loss:1.053, [valid] acc:0.973
# 169:72800 [train] loss:1.052, [valid] acc:0.971
# 169:72900 [train] loss:0.990, [valid] acc:0.971
# 169:73000 [train] loss:0.832, [valid] acc:0.975
# 170:73100 [train] loss:1.055, [valid] acc:0.971
# 170:73200 [train] loss:1.059, [valid] acc:0.974
# 170:73300 [train] loss:1.013, [valid] acc:0.972
# 170:73400 [train] loss:0.993, [valid] acc:0.972
# 170:73500 [train] loss:0.987, [valid] acc:0.971
# 171:73600 [train] loss:1.059, [valid] acc:0.974
# 171:73700 [train] loss:1.044, [valid] acc:0.972
# 171:73800 [train] loss:0.941, [valid] acc:0.972
# 171:73900 [train] loss:0.999, [valid] acc:0.974
# 172:74000 [train] loss:1.191, [valid] acc:0.974
# 172:74100 [train] loss:0.932, [valid] acc:0.972
# 172:74200 [train] loss:0.949, [valid] acc:0.973
# 172:74300 [train] loss:0.997, [valid] acc:0.975
# 173:74400 [train] loss:1.016, [valid] acc:0.972
# 173:74500 [train] loss:1.128, [valid] acc:0.973
# 173:74600 [train] loss:0.883, [valid] acc:0.974
# 173:74700 [train] loss:1.038, [valid] acc:0.973
# 173:74800 [train] loss:0.928, [valid] acc:0.974
# 174:74900 [train] loss:1.044, [valid] acc:0.971
# 174:75000 [train] loss:0.903, [valid] acc:0.973
# 174:75100 [train] loss:1.307, [valid] acc:0.974
# 174:75200 [train] loss:1.132, [valid] acc:0.972
# 175:75300 [train] loss:1.098, [valid] acc:0.973
# 175:75400 [train] loss:1.022, [valid] acc:0.972
# 175:75500 [train] loss:0.836, [valid] acc:0.973
# 175:75600 [train] loss:0.998, [valid] acc:0.975
# 176:75700 [train] loss:1.176, [valid] acc:0.974
# 176:75800 [train] loss:1.009, [valid] acc:0.973
# 176:75900 [train] loss:1.230, [valid] acc:0.973
# 176:76000 [train] loss:1.231, [valid] acc:0.973
# 176:76100 [train] loss:0.941, [valid] acc:0.973
# 177:76200 [train] loss:0.982, [valid] acc:0.972
# 177:76300 [train] loss:0.784, [valid] acc:0.972
# 177:76400 [train] loss:0.999, [valid] acc:0.972
# 177:76500 [train] loss:1.030, [valid] acc:0.971
# 178:76600 [train] loss:0.980, [valid] acc:0.971
# 178:76700 [train] loss:0.826, [valid] acc:0.967
# 178:76800 [train] loss:1.196, [valid] acc:0.970
# 178:76900 [train] loss:1.213, [valid] acc:0.973
# 179:77000 [train] loss:1.110, [valid] acc:0.972
# 179:77100 [train] loss:1.145, [valid] acc:0.972
# 179:77200 [train] loss:0.905, [valid] acc:0.969
# 179:77300 [train] loss:1.041, [valid] acc:0.971
# 180:77400 [train] loss:1.160, [valid] acc:0.975
# 180:77500 [train] loss:0.988, [valid] acc:0.970
# 180:77600 [train] loss:0.939, [valid] acc:0.970
# 180:77700 [train] loss:1.154, [valid] acc:0.972
# 180:77800 [train] loss:0.958, [valid] acc:0.972
# 181:77900 [train] loss:1.210, [valid] acc:0.971
# 181:78000 [train] loss:0.982, [valid] acc:0.972
# 181:78100 [train] loss:0.995, [valid] acc:0.975
# 181:78200 [train] loss:0.831, [valid] acc:0.974
# 182:78300 [train] loss:0.999, [valid] acc:0.974
# 182:78400 [train] loss:0.834, [valid] acc:0.971
# 182:78500 [train] loss:0.874, [valid] acc:0.973
# 182:78600 [train] loss:0.985, [valid] acc:0.973
# 183:78700 [train] loss:0.938, [valid] acc:0.972
# 183:78800 [train] loss:0.876, [valid] acc:0.971
# 183:78900 [train] loss:1.193, [valid] acc:0.973
# 183:79000 [train] loss:1.095, [valid] acc:0.973
# 183:79100 [train] loss:1.095, [valid] acc:0.976
# 184:79200 [train] loss:1.097, [valid] acc:0.974
# 184:79300 [train] loss:1.163, [valid] acc:0.973
# 184:79400 [train] loss:0.938, [valid] acc:0.975
# 184:79500 [train] loss:0.974, [valid] acc:0.974
# 185:79600 [train] loss:1.099, [valid] acc:0.973
# 185:79700 [train] loss:1.052, [valid] acc:0.973
# 185:79800 [train] loss:0.861, [valid] acc:0.973
# 185:79900 [train] loss:1.022, [valid] acc:0.971
# 186:80000 [train] loss:1.067, [valid] acc:0.974
# 186:80100 [train] loss:0.876, [valid] acc:0.973
# 186:80200 [train] loss:0.970, [valid] acc:0.972
# 186:80300 [train] loss:0.944, [valid] acc:0.973
# 186:80400 [train] loss:1.065, [valid] acc:0.973
# 187:80500 [train] loss:1.123, [valid] acc:0.974
# 187:80600 [train] loss:1.035, [valid] acc:0.973
# 187:80700 [train] loss:0.798, [valid] acc:0.971
# 187:80800 [train] loss:0.881, [valid] acc:0.974
# 188:80900 [train] loss:0.932, [valid] acc:0.976
# 188:81000 [train] loss:0.807, [valid] acc:0.972
# 188:81100 [train] loss:1.062, [valid] acc:0.972
# 188:81200 [train] loss:0.875, [valid] acc:0.973
# 189:81300 [train] loss:1.073, [valid] acc:0.972
# 189:81400 [train] loss:1.187, [valid] acc:0.972
# 189:81500 [train] loss:1.051, [valid] acc:0.974
# 189:81600 [train] loss:1.138, [valid] acc:0.973
# 190:81700 [train] loss:0.943, [valid] acc:0.970
# 190:81800 [train] loss:0.944, [valid] acc:0.968
# 190:81900 [train] loss:1.052, [valid] acc:0.974
# 190:82000 [train] loss:0.867, [valid] acc:0.972
# 190:82100 [train] loss:0.909, [valid] acc:0.973
# 191:82200 [train] loss:1.070, [valid] acc:0.971
# 191:82300 [train] loss:0.875, [valid] acc:0.971
# 191:82400 [train] loss:1.149, [valid] acc:0.974
# 191:82500 [train] loss:0.898, [valid] acc:0.974
# 192:82600 [train] loss:0.905, [valid] acc:0.976
# 192:82700 [train] loss:0.968, [valid] acc:0.974
# 192:82800 [train] loss:0.978, [valid] acc:0.974
# 192:82900 [train] loss:0.897, [valid] acc:0.973
# 193:83000 [train] loss:0.959, [valid] acc:0.971
# 193:83100 [train] loss:1.097, [valid] acc:0.973
# 193:83200 [train] loss:1.109, [valid] acc:0.971
# 193:83300 [train] loss:1.109, [valid] acc:0.973
# 193:83400 [train] loss:0.992, [valid] acc:0.973
# 194:83500 [train] loss:1.028, [valid] acc:0.974
# 194:83600 [train] loss:1.083, [valid] acc:0.971
# 194:83700 [train] loss:0.934, [valid] acc:0.971
# 194:83800 [train] loss:0.940, [valid] acc:0.973
# 195:83900 [train] loss:0.961, [valid] acc:0.972
# 195:84000 [train] loss:0.873, [valid] acc:0.973
# 195:84100 [train] loss:1.189, [valid] acc:0.972
# 195:84200 [train] loss:0.975, [valid] acc:0.973
# 196:84300 [train] loss:0.843, [valid] acc:0.971
# 196:84400 [train] loss:0.998, [valid] acc:0.971
# 196:84500 [train] loss:0.934, [valid] acc:0.973
# 196:84600 [train] loss:1.000, [valid] acc:0.975
# 196:84700 [train] loss:0.964, [valid] acc:0.976
# 197:84800 [train] loss:1.037, [valid] acc:0.975
# 197:84900 [train] loss:1.117, [valid] acc:0.973
# 197:85000 [train] loss:0.901, [valid] acc:0.973
# 197:85100 [train] loss:0.931, [valid] acc:0.974
# 198:85200 [train] loss:1.177, [valid] acc:0.974
# 198:85300 [train] loss:1.200, [valid] acc:0.972
# 198:85400 [train] loss:1.077, [valid] acc:0.972
# 198:85500 [train] loss:1.025, [valid] acc:0.973
# 199:85600 [train] loss:1.098, [valid] acc:0.973
# 199:85700 [train] loss:0.969, [valid] acc:0.973
# 199:85800 [train] loss:1.002, [valid] acc:0.972
# 199:85900 [train] loss:1.169, [valid] acc:0.973
# [test] acc:0.970
